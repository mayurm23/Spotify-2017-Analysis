# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('Spotify.csv')

# %%
data.head(20)
# Out:
#                        id                                               name  \
# 0   7qiZfU4dY1lWllzX7mPBI                                       Shape of You
# 1   5CtI0qwDJkDQGwXD1H1cL                                  Despacito - Remix
# 2   4aWmUDTfIPGksMNLV2rQP                 Despacito (Featuring Daddy Yankee)
# 3   6RUKPb4LETWmmr3iAEQkt                           Something Just Like This
# 4   3DXncPQOG4VBw3QHh3S81                                        I'm the One
# 5   7KXjTSCq5nL1LoYtL7XAw                                            HUMBLE.
# 6   3eR23VReFzcdmS7TYCrhC                    It Ain't Me (with Selena Gomez)
# 7   3B54sVLJ402zGa6Xm4YGN                                      Unforgettable
# 8   0KKkJNfGyhkQ5aFogxQAP                                 That's What I Like
# 9   3NdDpSvN911VPGivFlV5d  I Don’t Wanna Live Forever (Fifty Shades Darke...
# 10  7GX5flRQZVHRAGd6B4TmD                                      XO TOUR Llif3
# 11  72jbDTw1piOOj770jWNea                                              Paris
# 12  0dA2Mk56wEzDgegdC6R17                           Stay (with Alessia Cara)
# 13  4iLqG9SeJSnt0cSPICSjx                                          Attention
# 14  0VgkVdmE4gld66l8iyGjg                                           Mask Off
# 15  3a1lNhkSLSkpJE4MSHpDu                                    Congratulations
# 16  6kex4EBAj0WHXDKZMEJaa         Swalla (feat. Nicki Minaj & Ty Dolla $ign)
# 17  6PCUP3dWmTjcTtXY02oFd                                 Castle on the Hill
# 18  5knuzwU65gJK7IF5yJsua            Rockabye (feat. Sean Paul & Anne-Marie)
# 19  0CcQNd8CINkwQfe1RDtGV                                           Believer
#
#              artists  danceability  energy   key  loudness  mode  speechiness  \
# 0         Ed Sheeran         0.825   0.652   1.0    -3.183   0.0       0.0802
# 1         Luis Fonsi         0.694   0.815   2.0    -4.328   1.0       0.1200
# 2         Luis Fonsi         0.660   0.786   2.0    -4.757   1.0       0.1700
# 3   The Chainsmokers         0.617   0.635  11.0    -6.769   0.0       0.0317
# 4          DJ Khaled         0.609   0.668   7.0    -4.284   1.0       0.0367
# 5     Kendrick Lamar         0.904   0.611   1.0    -6.842   0.0       0.0888
# 6               Kygo         0.640   0.533   0.0    -6.596   1.0       0.0706
# 7     French Montana         0.726   0.769   6.0    -5.043   1.0       0.1230
# 8         Bruno Mars         0.853   0.560   1.0    -4.961   1.0       0.0406
# 9               ZAYN         0.735   0.451   0.0    -8.374   1.0       0.0585
# 10      Lil Uzi Vert         0.732   0.750  11.0    -6.366   0.0       0.2310
# 11  The Chainsmokers         0.653   0.658   2.0    -6.428   1.0       0.0304
# 12              Zedd         0.679   0.634   5.0    -5.024   0.0       0.0654
# 13      Charlie Puth         0.774   0.626   3.0    -4.432   0.0       0.0432
# 14            Future         0.833   0.434   2.0    -8.795   1.0       0.4310
# 15       Post Malone         0.627   0.812   6.0    -4.215   1.0       0.0358
# 16      Jason Derulo         0.696   0.817   1.0    -3.862   1.0       0.1090
# 17        Ed Sheeran         0.461   0.834   2.0    -4.868   1.0       0.0989
# 18      Clean Bandit         0.720   0.763   9.0    -4.068   0.0       0.0523
# 19   Imagine Dragons         0.779   0.787  10.0    -4.305   0.0       0.1080
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0       0.581000          0.000000    0.0931   0.9310   95.977     233713.0
# 1       0.229000          0.000000    0.0924   0.8130   88.931     228827.0
# 2       0.209000          0.000000    0.1120   0.8460  177.833     228200.0
# 3       0.049800          0.000014    0.1640   0.4460  103.019     247160.0
# 4       0.055200          0.000000    0.1670   0.8110   80.924     288600.0
# 5       0.000259          0.000020    0.0976   0.4000  150.020     177000.0
# 6       0.119000          0.000000    0.0864   0.5150   99.968     220781.0
# 7       0.029300          0.010100    0.1040   0.7330   97.985     233902.0
# 8       0.013000          0.000000    0.0944   0.8600  134.066     206693.0
# 9       0.063100          0.000013    0.3250   0.0862  117.973     245200.0
# 10      0.002640          0.000000    0.1090   0.4010  155.096     182707.0
# 11      0.021500          0.000002    0.0939   0.2190   99.990     221507.0
# 12      0.232000          0.000000    0.1150   0.4980  102.013     210091.0
# 13      0.096900          0.000031    0.0848   0.7770  100.041     211475.0
# 14      0.010200          0.021900    0.1650   0.2810  150.062     204600.0
# 15      0.198000          0.000000    0.2120   0.5040  123.071     220293.0
# 16      0.075000          0.000000    0.1870   0.7820   98.064     216409.0
# 17      0.023200          0.000011    0.1400   0.4710  135.007     261154.0
# 18      0.406000          0.000000    0.1800   0.7420  101.965     251088.0
# 19      0.052400          0.000000    0.1400   0.7080  124.982     204347.0
#
#     time_signature
# 0              4.0
# 1              4.0
# 2              4.0
# 3              4.0
# 4              4.0
# 5              4.0
# 6              4.0
# 7              4.0
# 8              4.0
# 9              4.0
# 10             4.0
# 11             4.0
# 12             4.0
# 13             4.0
# 14             4.0
# 15             4.0
# 16             4.0
# 17             4.0
# 18             4.0
# 19             4.0

# %%
data.describe(include="all")
# Out:
#                            id        name           artists  danceability  \
# count                     100         100               100     100.00000
# unique                    100         100                78           NaN
# top     1x5sYLZiu9r5E43kMlt9f  Slow Hands  The Chainsmokers           NaN
# freq                        1           1                 4           NaN
# mean                      NaN         NaN               NaN       0.69682
# std                       NaN         NaN               NaN       0.12508
# min                       NaN         NaN               NaN       0.25800
# 25%                       NaN         NaN               NaN       0.63500
# 50%                       NaN         NaN               NaN       0.71400
# 75%                       NaN         NaN               NaN       0.77025
# max                       NaN         NaN               NaN       0.92700
#
#             energy         key    loudness        mode  speechiness  \
# count   100.000000  100.000000  100.000000  100.000000   100.000000
# unique         NaN         NaN         NaN         NaN          NaN
# top            NaN         NaN         NaN         NaN          NaN
# freq           NaN         NaN         NaN         NaN          NaN
# mean      0.660690    5.570000   -5.652650    0.580000     0.103969
# std       0.139207    3.731534    1.802067    0.496045     0.095115
# min       0.346000    0.000000  -11.462000    0.000000     0.023200
# 25%       0.556500    2.000000   -6.594500    0.000000     0.043125
# 50%       0.667500    6.000000   -5.437000    1.000000     0.062650
# 75%       0.787500    9.000000   -4.326750    1.000000     0.123000
# max       0.932000   11.000000   -2.396000    1.000000     0.431000
#
#         acousticness  instrumentalness    liveness     valence       tempo  \
# count     100.000000        100.000000  100.000000  100.000000  100.000000
# unique           NaN               NaN         NaN         NaN         NaN
# top              NaN               NaN         NaN         NaN         NaN
# freq             NaN               NaN         NaN         NaN         NaN
# mean        0.166306          0.004796    0.150607    0.517049  119.202460
# std         0.166730          0.026038    0.079011    0.216436   27.952928
# min         0.000259          0.000000    0.042400    0.086200   75.016000
# 25%         0.039100          0.000000    0.098275    0.375500   99.911750
# 50%         0.106500          0.000000    0.125000    0.502500  112.468000
# 75%         0.231250          0.000013    0.179250    0.679000  137.166000
# max         0.695000          0.210000    0.440000    0.966000  199.864000
#
#          duration_ms  time_signature
# count      100.00000          100.00
# unique           NaN             NaN
# top              NaN             NaN
# freq             NaN             NaN
# mean    218387.28000            3.99
# std      32851.07772            0.10
# min     165387.00000            3.00
# 25%     198490.50000            4.00
# 50%     214106.00000            4.00
# 75%     230543.00000            4.00
# max     343150.00000            4.00

# %%
num= data.drop(['id','name','artists','tempo','duration_ms','key','loudness','time_signature'], axis=1)

# %%
sns.set_palette('deep')

# %%
plt.subplots(figsize=(12,10))
artist = data['artists'].groupby(data['artists']).count().sort_values(ascending=False)
plt.xlabel('Artists',size=12)
plt.xticks(size=15)
plt.ylabel('Count',size=12)
plt.title('Artists with Most Songs in Top 100',size=20)
gh.head(10).plot('bar')

# %%
num.mean().plot.bar()
plt.title('Mean Values of Audio Features')
plt.show()

# %%
print("Mean value for Danceability:", data['danceability'].mean())
sns.distplot(data['danceability'])
plt.xlabel('Danceability',size=12)
plt.show()
# Out:
# Mean value for Danceability: 0.6968199999999999

# %%
print("Mean value for energy:", data['energy'].mean())
sns.distplot(data['energy'])
plt.xlabel('Energy',size=12)
plt.show()
# Out:
# Mean value for energy: 0.6606899999999999

# %%
print("Mean value for loudness:", data['loudness'].mean())
sns.distplot(data['loudness'])
plt.xlabel('Loudness',size=12)
plt.show()
# Out:
# Mean value for loudness: -5.652649999999998

# %%
print("Mean value for speechiness:", data['speechiness'].mean())
sns.distplot(data['speechiness'])
plt.xlabel('Speechiness',size=12)
plt.show()
# Out:
# Mean value for speechiness: 0.10396899999999995

# %%
print("Mean value for acousticness:", data['acousticness'].mean())
sns.distplot(data['acousticness'])
plt.xlabel('Acousticness',size=12)
plt.show()
# Out:
# Mean value for acousticness: 0.16630649000000006

# %%
print("Mean value for instrumentalness:", data['instrumentalness'].mean())
sns.distplot(data['instrumentalness'])
plt.xlabel('Instrumentalness',size=12)
plt.show()
# Out:
# Mean value for instrumentalness: 0.0047961442

# %%
print("Mean value for liveness:valen", data['liveness'].mean())
sns.distplot(data['liveness'])
plt.xlabel('Liveness',size=12)
plt.show()
# Out:
# Mean value for liveness:valen 0.15060700000000002

# %%
print('Mean value for valence feature:', data['valence'].mean())
sns.distplot(data['valence'])
plt.xlabel('Valence',size=12)
plt.show()
# Out:
# Mean value for valence feature: 0.5170489999999999

# %%
print('Mean value for tempo feature:', data['tempo'].mean(),'bpm')
sns.distplot(data['tempo'])
plt.xlabel('Tempo',size=12)
plt.show()
# Out:
# Mean value for tempo feature: 119.20245999999996 bpm

# %%
print('Mean value for Duration (milliseconds):', data['duration_ms'].mean(),'ms')
sns.distplot(data['duration_ms'])
plt.xlabel('Duration (milliseconds',size=12)
plt.show()
# Out:
# Mean value for Duration (milliseconds): 218387.28 ms
